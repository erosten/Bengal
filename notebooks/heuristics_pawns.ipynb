# %%
import sys, os
sys.path.append(os.path.dirname(os.path.abspath('')))
from src.hueristic import Hueristic
from src.utils import display
import chess
from chess import SquareSet as ss

sep = '-'*20
f = Hueristic()
b = chess.Board(fen = '8/8/4pPP1/1p2P3/1P6/1P6/8/8 w - - 0 1')
c = chess.WHITE
display(b)
f.set(b)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_8540/3118361179.py in <module>
#       1 import sys, os
# ----> 2 sys.path.append(os.path.dirname(os.path.abspath(__file__)))
#       3 from src.ai.evaluations.hueristic import Hueristic
#       4 from src.utils import display
#       5 import chess
#
# NameError: name '__file__' is not defined

# %%
for pawn in f.pieces[c][chess.PAWN]:
    print(ss([pawn]), '\n')
    print('Blocked: ', f._blocked(ss([pawn]), c))
    print('Doubled: ', f._doubled(ss([pawn]), c))
    print('Doubled isolated: ', f._doubled_isolated(pawn, ss([pawn]), c))
    print('Isolated: ', f._isolated(pawn, c))
    print('phalanx: ', f._phalanx(ss([pawn]), c))
    print('supported: ', f._supported(ss([pawn]), c))
    print('opposed: ', f._opposed(ss([pawn]), c))
# Out:
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . 1 . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Blocked:  True
# Doubled:  False
# Doubled isolated:  False
# Isolated:  True
# phalanx:  False
# supported:  False
# opposed:  False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . 1 . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Blocked:  False
# Doubled:  True
# Doubled isolated:  True
# Isolated:  True
# phalanx:  False
# supported:  False
# opposed:  True
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . 1 . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Blocked:  False
# Doubled:  False
# Doubled isolated:  False
# Isolated:  False
# phalanx:  False
# supported:  False
# opposed:  True
# . . . . . . . .
# . . . . . . . .
# . . . . . 1 . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# ...

# %%
sep = '-'*20
f = Hueristic()
b = chess.Board(fen = '8/4p3/4p2p/1p2PppP/1P6/8/8/8 b - - 0 1')
c = chess.BLACK
display(b)
f.set(b)
# Out:
# ------------------------------------------------------------------
#
#
# 8 ♢ ♢ ♢ ♢ ♢ ♢ ♢ ♢
# 7 ♢ ♢ ♢ ♢ ♙ ♢ ♢ ♢
# 6 ♢ ♢ ♢ ♢ ♙ ♢ ♢ ♙
# 5 ♢ ♙ ♢ ♢ ♟ ♙ ♙ ♟
# 4 ♢ ♟ ♢ ♢ ♢ ♢ ♢ ♢
# 3 ♢ ♢ ♢ ♢ ♢ ♢ ♢ ♢
# 2 ♢ ♢ ♢ ♢ ♢ ♢ ♢ ♢
# 1 ♢ ♢ ♢ ♢ ♢ ♢ ♢ ♢
#   A B C D E F G H
#
# ------------------------------------------------------------------

# %%
for pawn in f.pieces[c][chess.PAWN]:
    print(ss([pawn]), '\n')
    print('Blocked: ', f._blocked(ss([pawn]), c))
    print('Doubled: ', f._doubled(ss([pawn]), c))
    print('Doubled isolated: ', f._doubled_isolated(pawn, ss([pawn]), c))
    print('Isolated: ', f._isolated(pawn, c))
    print('phalanx: ', f._phalanx(ss([pawn]), c))
    print('supported: ', f._supported(ss([pawn]), c))
    print('opposed: ', f._opposed(ss([pawn]), c))
# Out:
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . 1 . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Blocked:  False
# Doubled:  False
# Doubled isolated:  False
# Isolated:  True
# phalanx:  False
# supported:  False
# opposed:  True
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . 1 . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Blocked:  False
# Doubled:  False
# Doubled isolated:  False
# Isolated:  False
# phalanx:  True
# supported:  True
# opposed:  False
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . 1 .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# Blocked:  False
# Doubled:  False
# Doubled isolated:  False
# Isolated:  False
# phalanx:  True
# supported:  True
# opposed:  False
# . . . . . . . .
# . . . . . . . .
# . . . . 1 . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
# . . . . . . . .
#
# ...
